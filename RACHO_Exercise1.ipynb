# %% [markdown]
# # Exercise 1

# %% [markdown]
# ## Class Initialization

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

# %%
class LinkedList:

    def __init__(self):
        self.head = None

    def traverse(self, node):
        while node:
            print(node.data, end=" -> ")
            node = node.next

# %%
class DoublyLinkedList:

    def __init__(self):
        self.head = None

    def traverse(self, node):
        while node:
            print(node.data, end=" -> ")
            node = node.next

# %%
class CircularLinkedList:

    def __init__(self):
        self.head = None

    def traverse(self, node):

        head = node

        while node:
            print(node.data, end=" -> ")
            node = node.next

            # Break to prevent infinite loop
            if node == head:
                break

# %% [markdown]
# #### 1. Create a Singly Linked list
#
# - Each node should contain your name and your seatmates in your row
# - Create at least 5 nodes
# - Traverse all nodes

# %%
singlyLinkedList = LinkedList()

# %%
singlyLinkedList.head = Node("Charles Angelo Racho")
node_b = Node("John Paul Ferido")
node_c = Node("Butchoy Pasco")
node_d = Node("Elijah Martin Cruz")
node_e = Node("Mark Jasper Iglesias")

# %%
singlyLinkedList.head.next = node_b
node_b.next = node_c
node_c.next = node_d
node_d.next = node_e

# %%
singlyLinkedList.traverse(singlyLinkedList.head)
# Out:
# Charles Angelo Racho -> John Paul Ferido -> Butchoy Pasco -> Elijah Martin Cruz -> Mark Jasper Iglesias ->

# %% [markdown]
# #### 2. Create a Doubly Linked list
#
# - Each node should contain your name and your seatmates in your row
# - Create at least 5 nodes
# - Traverse all nodes

# %%
doublyLinkedList = DoublyLinkedList()

# %%
doublyLinkedList.head = Node("Charles Angelo Racho")
node_b = Node("John Paul Ferido")
node_c = Node("Butchoy Pasco")
node_d = Node("Elijah Martin Cruz")
node_e = Node("Mark Jasper Iglesias")

# %%
doublyLinkedList.head.prev = None
doublyLinkedList.head.next = node_b

node_b.prev = doublyLinkedList.head
node_b.next = node_c

node_c.prev = node_b
node_c.next = node_d

node_d.prev = node_c
node_d.next = node_e

node_e.prev = node_d
node_e.next = None

# %%
print("value of previous to head is: ", doublyLinkedList.head.prev)
print("value of head is :", doublyLinkedList.head.data)
print("value of next to head is :", doublyLinkedList.head.next.data)

print("---")

print("value of node_b is :", node_b.data)
print("value of previous of node_b is :", node_b.prev.data)
print("value of next of node_b is :", node_b.next.data)

print("---")

print("value of node_c is :", node_c.data)
print("value of previous of node_c is :", node_c.prev.data)
print("value of next of node_c is :", node_c.next.data)

print("---")

print("value of node_d is :", node_d.data)
print("value of previous of node_d is :", node_d.prev.data)
print("value of next of node_d is :", node_d.next.data)

print("---")

print("value of node_e is :", node_e.data)
print("value of previous of node_e is :", node_e.prev.data)
print("value of next of node_e is :", node_e.next)
# Out:
# value of previous to head is:  None
# value of head is : Charles Angelo Racho
# value of next to head is : John Paul Ferido
# ---
# value of node_b is : John Paul Ferido
# value of previous of node_b is : Charles Angelo Racho
# value of next of node_b is : Butchoy Pasco
# ---
# value of node_c is : Butchoy Pasco
# value of previous of node_c is : John Paul Ferido
# value of next of node_c is : Elijah Martin Cruz
# ---
# value of node_d is : Elijah Martin Cruz
# value of previous of node_d is : Butchoy Pasco
# value of next of node_d is : Mark Jasper Iglesias
# ---
# value of node_e is : Mark Jasper Iglesias
# value of previous of node_e is : Elijah Martin Cruz
# value of next of node_e is : None

# %%
doublyLinkedList.traverse(doublyLinkedList.head)
# Out:
# Charles Angelo Racho -> John Paul Ferido -> Butchoy Pasco -> Elijah Martin Cruz -> Mark Jasper Iglesias ->

# %% [markdown]
# #### 3. Create a Circular Linked list
#
# - Each node should contain your name and your seatmates in your row
# - Create at least 5 nodes
# - Traverse all nodes

# %%
circularLinkedList = CircularLinkedList()

# %%
circularLinkedList.head = Node("Charles Angelo Racho")
node_b = Node("John Paul Ferido")
node_c = Node("Butchoy Pasco")
node_d = Node("Elijah Martin Cruz")
node_e = Node("Mark Jasper Iglesias")

# %%
circularLinkedList.head.next = node_b
node_b.next = node_c
node_c.next = node_d
node_d.next = node_e
node_e.next = circularLinkedList.head

# %%
circularLinkedList.traverse(circularLinkedList.head)
# Out:
# Charles Angelo Racho -> John Paul Ferido -> Butchoy Pasco -> Elijah Martin Cruz -> Mark Jasper Iglesias ->
